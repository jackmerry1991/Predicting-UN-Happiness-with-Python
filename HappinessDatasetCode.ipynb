# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv(r'C:\Users\jackm\Documents\Data Analytics\CW\world-happiness (1)\2017.csv')

# %%
df2 = pd.read_csv(r'C:\Users\jackm\Documents\Data Analytics\CW\undata-country-profiles\country_profile_variables.csv')

# %%
df.head()
# Out:
#        Country  Happiness.Rank  Happiness.Score  Whisker.high  Whisker.low  \
# 0       Norway               1            7.537      7.594445     7.479556
# 1      Denmark               2            7.522      7.581728     7.462272
# 2      Iceland               3            7.504      7.622030     7.385970
# 3  Switzerland               4            7.494      7.561772     7.426227
# 4      Finland               5            7.469      7.527542     7.410458
#
#    Economy..GDP.per.Capita.    Family  Health..Life.Expectancy.   Freedom  \
# 0                  1.616463  1.533524                  0.796667  0.635423
# 1                  1.482383  1.551122                  0.792566  0.626007
# 2                  1.480633  1.610574                  0.833552  0.627163
# 3                  1.564980  1.516912                  0.858131  0.620071
# 4                  1.443572  1.540247                  0.809158  0.617951
#
#    Generosity  Trust..Government.Corruption.  Dystopia.Residual
# ...

# %%
df2.head()
# Out:
#           country          Region Surface area (km2)  \
# 0     Afghanistan    SouthernAsia             652864
# 1         Albania  SouthernEurope              28748
# 2         Algeria  NorthernAfrica            2381741
# 3  American Samoa       Polynesia                199
# 4         Andorra  SouthernEurope                468
#
#    Population in thousands (2017)  Population density (per km2, 2017)  \
# 0                           35530                                54.4
# 1                            2930                               106.9
# 2                           41318                                17.3
# 3                              56                               278.2
# 4                              77                               163.8
#
#    Sex ratio (m per 100 f, 2017)  \
# 0                          106.3
# 1                          101.9
# 2                          102.0
# 3                          103.6
# 4                          102.3
#
# ...

# %%
#Rename column of country in df2 to match df
df_renamed = df2.rename(columns = {'country': 'Country'})

# %%
df_renamed
# Out:
#                        Country          Region Surface area (km2)  \
# 0                  Afghanistan    SouthernAsia             652864
# 1                      Albania  SouthernEurope              28748
# 2                      Algeria  NorthernAfrica            2381741
# 3               American Samoa       Polynesia                199
# 4                      Andorra  SouthernEurope                468
# ..                         ...             ...                ...
# 224  Wallis and Futuna Islands       Polynesia                142
# 225             Western Sahara  NorthernAfrica             266000
# 226                      Yemen     WesternAsia             527968
# 227                     Zambia   EasternAfrica             752612
# 228                   Zimbabwe   EasternAfrica             390757
#
#      Population in thousands (2017)  Population density (per km2, 2017)  \
# 0                             35530                                54.4
# ...

# %%
#Strip Whitespace in Country names to ensure they match
df['Country'] = df['Country'].str.replace(" ", "")
df['Country'] = df['Country'].str.upper() 
df.to_csv(r'C:\Users\jackm\Documents\Data Analytics\CW\TrimHappiness.csv', index = False)

df_renamed['Country'] = df_renamed['Country'].str.replace(" ", "")
df_renamed['Country'] = df_renamed['Country'].str.upper() 
df_renamed.to_csv(r'C:\Users\jackm\Documents\Data Analytics\CW\TrimStats.csv', index = False)
# Out:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# <ipython-input-7-231e04b5ce18> in <module>
#       6 df_renamed['Country'] = df_renamed['Country'].str.replace(" ", "")
#       7 df_renamed['Country'] = df_renamed['Country'].str.upper()
# ----> 8 df_renamed.to_csv(r'C:\Users\jackm\Documents\Data Analytics\CW\TrimStats.csv', index = False)
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, line_terminator, chunksize, date_format, doublequote, escapechar, decimal)
#    3226             decimal=decimal,
#    3227         )
# -> 3228         formatter.save()
#    3229
#    3230         if path_or_buf is None:
#
# ~\Anaconda3\lib\site-packages\pandas\io\formats\csvs.py in save(self)
#     181                 self.mode,
# ...

# %%
df_merged=pd.merge(df, df_renamed, left_on='Country', right_on='Country')

# %%
df_merged
# Out:
#                     Country  Happiness.Rank  Happiness.Score  Whisker.high  \
# 0                    NORWAY               1            7.537      7.594445
# 1                   DENMARK               2            7.522      7.581728
# 2                   ICELAND               3            7.504      7.622030
# 3               SWITZERLAND               4            7.494      7.561772
# 4                   FINLAND               5            7.469      7.527542
# ..                      ...             ...              ...           ...
# 132                  GUINEA             149            3.507      3.584428
# 133                    TOGO             150            3.495      3.594038
# 134                  RWANDA             151            3.471      3.543030
# 135                 BURUNDI             154            2.905      3.074690
# 136  CENTRALAFRICANREPUBLIC             155            2.693      2.864884
#
#      Whisker.low  Economy..GDP.per.Capita.    Family  \
# ...

# %%
df_merged.to_csv(r'C:\Users\jackm\Documents\Data Analytics\CW\2017Merge.csv', index = False)

# %%
#outerjoin to determine missing values 
df_missing = pd.merge(df, df_renamed, on ='Country', how='left')

# %%
#Check how many countries are missing = 18 missing counties
df_missing.isnull().sum()
# Out:
# Country                                                        0
# Happiness.Rank                                                 0
# Happiness.Score                                                0
# Whisker.high                                                   0
# Whisker.low                                                    0
#                                                               ..
# Energy production, primary (Petajoules)                       18
# Energy supply per capita (Gigajoules)                         18
# Pop. using improved drinking water (urban/rural, %)           18
# Pop. using improved sanitation facilities (urban/rural, %)    18
# Net Official Development Assist. received (% of GNI)          18
# Length: 61, dtype: int64

# %%
#Create a new dataframe of all null values, provides list of the missing countries and shows difference in names that explains why

null_data = df_missing[df_missing.isnull().any(axis=1)]

# %%
print(null_data)
# Out:
#                     Country  Happiness.Rank  Happiness.Score  Whisker.high  \
# 13             UNITEDSTATES              14            6.993      7.074657
# 32    TAIWANPROVINCEOFCHINA              33            6.422      6.494596
# 48                   RUSSIA              49            5.963      6.030275
# 54               SOUTHKOREA              55            5.838      5.922559
# 55                  MOLDOVA              56            5.838      5.908371
# 57                  BOLIVIA              58            5.823      5.903977
# 60              NORTHCYPRUS              61            5.810      5.897366
# 70     HONGKONGS.A.R.,CHINA              71            5.472      5.549594
# 77                   KOSOVO              78            5.279      5.364848
# 81                VENEZUELA              82            5.250      5.370032
# 91                MACEDONIA              92            5.175      5.272173
# ...

# %%
#check for strings containing country names to determine why join didn't occur
df_renamed[df_renamed['Country'].str.contains("UNITEDSTATES")]
# Out:
#                        Country           Region Surface area (km2)  \
# 217      UNITEDSTATESOFAMERICA  NorthernAmerica            9833517
# 218  UNITEDSTATESVIRGINISLANDS        Caribbean                347
#
#      Population in thousands (2017)  Population density (per km2, 2017)  \
# 217                          324460                                35.5
# 218                             105                               299.7
#
#      Sex ratio (m per 100 f, 2017)  \
# 217                           98.0
# 218                           91.1
#
#      GDP: Gross domestic product (million current US$)  \
# 217                                           18036648
# 218                                                -99
#
#     GDP growth rate (annual %, const. 2005 prices)  \
# 217                                            2.6
# 218                                            -99
#
#      GDP per capita (current US$) Economy: Agriculture (% of GVA)  ...  \
# ...

# %%
#change to united states
df_renamed['Country'] = df_renamed['Country'].replace(['UNITEDSTATESOFAMERICA'], ['UNITEDSTATES'])

# %%
#check for Taiwan, not included as it is counted as province of China in National Statistics data set
df_renamed[df_renamed['Country'].str.contains("TAIW")]
# Out:
# Empty DataFrame
# ...

# %%
#check for Russia
df_renamed[df_renamed['Country'].str.contains("RUSSIA")]
# Out:
#                Country         Region Surface area (km2)  \
# 167  RUSSIANFEDERATION  EasternEurope           17098246
#
#      Population in thousands (2017)  Population density (per km2, 2017)  \
# 167                          143990                                 8.8
#
#      Sex ratio (m per 100 f, 2017)  \
# 167                           86.8
#
#      GDP: Gross domestic product (million current US$)  \
# 167                                            1326016
#
#     GDP growth rate (annual %, const. 2005 prices)  \
# 167                                           -3.7
#
#      GDP per capita (current US$) Economy: Agriculture (% of GVA)  ...  \
# 167                        9243.3                             4.7  ...
#
#      Mobile-cellular subscriptions (per 100 inhabitants).1  \
# 167                                               73.4
#
#      Individuals using the Internet (per 100 inhabitants)  \
# 167                                                235
#
# ...

# %%
#Change to Russia in both sets
df_renamed['Country'] = df_renamed['Country'].replace(['RUSSIANFEDERATION'], ['RUSSIA'])

# %%
#Check South Korea
df_renamed[df_renamed['Country'].str.contains("KOREA")]
# Out:
#                                Country       Region Surface area (km2)  \
# 55   DEMOCRATICPEOPLE'SREPUBLICOFKOREA  EasternAsia             120538
# 164                    REPUBLICOFKOREA  EasternAsia             100284
#
#      Population in thousands (2017)  Population density (per km2, 2017)  \
# 55                            25491                               211.7
# 164                           50982                               524.3
#
#      Sex ratio (m per 100 f, 2017)  \
# 55                            95.7
# 164                          100.2
#
#      GDP: Gross domestic product (million current US$)  \
# 55                                               16283
# 164                                            1377873
#
#     GDP growth rate (annual %, const. 2005 prices)  \
# 55                                            -1.1
# 164                                            2.6
#
#      GDP per capita (current US$) Economy: Agriculture (% of GVA)  ...  \
# ...

# %%
#CHANGE TO SOUTH KOREA
df_renamed['Country'] = df_renamed['Country'].replace(['REPUBLICOFKOREA'], ['SOUTHKOREA'])

# %%
#check Moldova
df_renamed[df_renamed['Country'].str.contains("MOLD")]
# Out:
#                Country         Region Surface area (km2)  \
# 165  REPUBLICOFMOLDOVA  EasternEurope              33846
#
#      Population in thousands (2017)  Population density (per km2, 2017)  \
# 165                            4051                               123.3
#
#      Sex ratio (m per 100 f, 2017)  \
# 165                           92.2
#
#      GDP: Gross domestic product (million current US$)  \
# 165                                               6475
#
#     GDP growth rate (annual %, const. 2005 prices)  \
# 165                                           -0.7
#
#      GDP per capita (current US$) Economy: Agriculture (% of GVA)  ...  \
# 165                        1591.4                            13.4  ...
#
#      Mobile-cellular subscriptions (per 100 inhabitants).1  \
# 165                                               49.8
#
#      Individuals using the Internet (per 100 inhabitants)  \
# 165                                                 35
#
# ...

# %%
#CHANGE TO MOLDOVA
df_renamed['Country'] = df_renamed['Country'].replace(['REPUBLICOFMOLDOVA'], ['MOLDOVA'])

# %%
#check Bolivia
df_renamed[df_renamed['Country'].str.contains("BOL")]
# Out:
#                              Country        Region Surface area (km2)  \
# 24     BOLIVIA(PLURINATIONALSTATEOF)  SouthAmerica            1098581
# 222  VENEZUELA(BOLIVARIANREPUBLICOF)  SouthAmerica             912050
#
#      Population in thousands (2017)  Population density (per km2, 2017)  \
# 24                            11052                                10.2
# 222                           31977                                36.3
#
#      Sex ratio (m per 100 f, 2017)  \
# 24                           100.2
# 222                           99.0
#
#      GDP: Gross domestic product (million current US$)  \
# 24                                               32998
# 222                                             344331
#
#     GDP growth rate (annual %, const. 2005 prices)  \
# 24                                             4.8
# 222                                           -6.2
#
#      GDP per capita (current US$) Economy: Agriculture (% of GVA)  ...  \
# ...

# %%
#CHANGE BOLIVIA
df_renamed['Country']= df_renamed['Country'].replace(['BOLIVIA(PLURINATIONALSTATEOF)'], ['BOLIVIA'])

# %%
#Cyprus is combined in one dataset and not in the other, in order to keep data accurate Cyprus will be dropped
df_renamed[df_renamed['Country'].str.contains("CYPRUS")]
# Out:
#    Country       Region Surface area (km2)  Population in thousands (2017)  \
# 53  CYPRUS  WesternAsia               9251                            1180
#
#     Population density (per km2, 2017)  Sex ratio (m per 100 f, 2017)  \
# 53                               127.7                          100.2
#
#     GDP: Gross domestic product (million current US$)  \
# 53                                              19561
#
#    GDP growth rate (annual %, const. 2005 prices)  \
# 53                                            1.7
#
#     GDP per capita (current US$) Economy: Agriculture (% of GVA)  ...  \
# 53                       21941.9                             2.3  ...
#
#     Mobile-cellular subscriptions (per 100 inhabitants).1  \
# 53                                               71.7
#
#     Individuals using the Internet (per 100 inhabitants)  \
# 53                                                 72
#
#    Threatened species (number) Forested area (% of land area)  \
# ...

# %%
#Hong Kong
df_renamed[df_renamed['Country'].str.contains("HONG")]
# Out:
#               Country       Region Surface area (km2)  \
# 43  CHINA,HONGKONGSAR  EasternAsia               1106
#
#     Population in thousands (2017)  Population density (per km2, 2017)  \
# 43                            7365                              7014.2
#
#     Sex ratio (m per 100 f, 2017)  \
# 43                           85.1
#
#     GDP: Gross domestic product (million current US$)  \
# 43                                             309236
#
#    GDP growth rate (annual %, const. 2005 prices)  \
# 43                                            2.4
#
#     GDP per capita (current US$) Economy: Agriculture (% of GVA)  ...  \
# 43                       42431.0                             0.1  ...
#
#     Mobile-cellular subscriptions (per 100 inhabitants).1  \
# 43                                               84.9
#
#     Individuals using the Internet (per 100 inhabitants)  \
# 43                                                 64
#
# ...

# %%
#Hong Kong change
df_renamed['Country']=df_renamed['Country'].replace(['CHINA,HONGKONGSAR'], ['HONGKONGS.A.R.,CHINA'])

# %%
#Kosovo not included, partially recognised so missing
df_renamed[df_renamed['Country'].str.contains("KOSOVO")]
# Out:
# Empty DataFrame
# ...

# %%
#VENEZUELA
df_renamed[df_renamed['Country'].str.contains("VENEZ")]
# Out:
#                              Country        Region Surface area (km2)  \
# 222  VENEZUELA(BOLIVARIANREPUBLICOF)  SouthAmerica             912050
#
#      Population in thousands (2017)  Population density (per km2, 2017)  \
# 222                           31977                                36.3
#
#      Sex ratio (m per 100 f, 2017)  \
# 222                           99.0
#
#      GDP: Gross domestic product (million current US$)  \
# 222                                             344331
#
#     GDP growth rate (annual %, const. 2005 prices)  \
# 222                                           -6.2
#
#      GDP per capita (current US$) Economy: Agriculture (% of GVA)  ...  \
# 222                       11068.9                             5.3  ...
#
#      Mobile-cellular subscriptions (per 100 inhabitants).1  \
# 222                                               61.9
#
#      Individuals using the Internet (per 100 inhabitants)  \
# ...

# %%
#Venezuela change
df_renamed['Country']=df_renamed['Country'].replace(['VENEZUELA(BOLIVARIANREPUBLICOF)'], ['VENEZUELA'])

# %%
#Macedonia
df_renamed[df_renamed['Country'].str.contains("MACEDONIA")]
# Out:
#                                   Country          Region Surface area (km2)  \
# 201  THEFORMERYUGOSLAVREPUBLICOFMACEDONIA  SouthernEurope              25713
#
#      Population in thousands (2017)  Population density (per km2, 2017)  \
# 201                            2083                                82.6
#
#      Sex ratio (m per 100 f, 2017)  \
# 201                          100.0
#
#      GDP: Gross domestic product (million current US$)  \
# 201                                              10052
#
#     GDP growth rate (annual %, const. 2005 prices)  \
# 201                                            3.8
#
#      GDP per capita (current US$) Economy: Agriculture (% of GVA)  ...  \
# 201                        4836.1                              12  ...
#
#      Mobile-cellular subscriptions (per 100 inhabitants).1  \
# 201                                               70.4
#
#      Individuals using the Internet (per 100 inhabitants)  \
# ...

# %%
#Macedonia change
df_renamed['Country']=df_renamed['Country'].replace(['THEFORMERYUGOSLAVREPUBLICOFMACEDONIA'], ['MACEDONIA'])

# %%
#Palestinian Territories
df_renamed[df_renamed['Country'].str.contains("PALES")]
# Out:
#               Country       Region Surface area (km2)  \
# 192  STATEOFPALESTINE  WesternAsia               6020
#
#      Population in thousands (2017)  Population density (per km2, 2017)  \
# 192                            4921                               817.4
#
#      Sex ratio (m per 100 f, 2017)  \
# 192                          102.9
#
#      GDP: Gross domestic product (million current US$)  \
# 192                                              12677
#
#     GDP growth rate (annual %, const. 2005 prices)  \
# 192                                            3.5
#
#      GDP per capita (current US$) Economy: Agriculture (% of GVA)  ...  \
# 192                        2715.5                             4.8  ...
#
#      Mobile-cellular subscriptions (per 100 inhabitants).1  \
# 192                                               57.4
#
#      Individuals using the Internet (per 100 inhabitants)  \
# 192                                                 31
#
# ...

# %%
#Palestine change
df_renamed['Country']=df_renamed['Country'].replace(['STATEOFPALESTINE'], ['PALESTINIANTERRITORIES'])

# %%
#Search Iran
df_renamed[df_renamed['Country'].str.contains("IRAN")]
# Out:
#                     Country        Region Surface area (km2)  \
# 97  IRAN(ISLAMICREPUBLICOF)  SouthernAsia            1628750
#
#     Population in thousands (2017)  Population density (per km2, 2017)  \
# 97                           81163                                49.8
#
#     Sex ratio (m per 100 f, 2017)  \
# 97                          101.2
#
#     GDP: Gross domestic product (million current US$)  \
# 97                                             398563
#
#    GDP growth rate (annual %, const. 2005 prices)  \
# 97                                            0.4
#
#     GDP per capita (current US$) Economy: Agriculture (% of GVA)  ...  \
# 97                        5038.1                             8.6  ...
#
#     Mobile-cellular subscriptions (per 100 inhabitants).1  \
# 97                                               44.1
#
#     Individuals using the Internet (per 100 inhabitants)  \
# 97                                                134
#
# ...

# %%
#Change Iran
df_renamed['Country']=df_renamed['Country'].replace(['IRAN(ISLAMICREPUBLICOF)'], ['IRAN'])

# %%
#Congo
df_renamed[df_renamed['Country'].str.contains("CONGO")]
# Out:
#                          Country        Region Surface area (km2)  \
# 48                         CONGO  MiddleAfrica             342000
# 56  DEMOCRATICREPUBLICOFTHECONGO  MiddleAfrica            2344858
#
#     Population in thousands (2017)  Population density (per km2, 2017)  \
# 48                            5261                                15.4
# 56                           81340                                35.9
#
#     Sex ratio (m per 100 f, 2017)  \
# 48                          100.1
# 56                           99.6
#
#     GDP: Gross domestic product (million current US$)  \
# 48                                               8493
# 56                                              37569
#
#    GDP growth rate (annual %, const. 2005 prices)  \
# 48                                            1.2
# 56                                              7
#
#     GDP per capita (current US$) Economy: Agriculture (% of GVA)  ...  \
# ...

# %%
#rename both based on capital
df_renamed['Country']=df_renamed['Country'].replace(['CONGO'], ['CONGO(BRAZZAVILLE)'])
df_renamed['Country']=df_renamed['Country'].replace(['DEMOCRATICREPUBLICOFTHECONGO'], ['CONGO(KINSHASA)'])

# %%
#Ivory Coast does not seem to appear in dataset, also tried under alternative Côte d'Ivoire
df_renamed[df_renamed['Country'].str.contains("IVORY")]
# Out:
# Empty DataFrame
# ...

# %%
#Syria
df_renamed[df_renamed['Country'].str.contains("SYRIA")]
# Out:
#                 Country       Region Surface area (km2)  \
# 198  SYRIANARABREPUBLIC  WesternAsia             185180
#
#      Population in thousands (2017)  Population density (per km2, 2017)  \
# 198                           18270                                99.5
#
#      Sex ratio (m per 100 f, 2017)  \
# 198                          102.1
#
#      GDP: Gross domestic product (million current US$)  \
# 198                                              28393
#
#     GDP growth rate (annual %, const. 2005 prices)  \
# 198                                           -5.3
#
#      GDP per capita (current US$) Economy: Agriculture (% of GVA)  ...  \
# 198                        1534.5                            20.7  ...
#
#      Mobile-cellular subscriptions (per 100 inhabitants).1  \
# 198                                                 30
#
#      Individuals using the Internet (per 100 inhabitants)  \
# 198                                                132
#
# ...

# %%
#Syria change
df_renamed['Country']=df_renamed['Country'].replace(['SYRIANARABREPUBLIC'], ['SYRIA'])

# %%
df_renamed[df_renamed['Country'].str.contains("TANZ")]
# Out:
#                       Country         Region Surface area (km2)  \
# 216  UNITEDREPUBLICOFTANZANIA  EasternAfrica             947303
#
#      Population in thousands (2017)  Population density (per km2, 2017)  \
# 216                           57310                                64.7
#
#      Sex ratio (m per 100 f, 2017)  \
# 216                           97.8
#
#      GDP: Gross domestic product (million current US$)  \
# 216                                              45628
#
#     GDP growth rate (annual %, const. 2005 prices)  \
# 216                                              7
#
#      GDP per capita (current US$) Economy: Agriculture (% of GVA)  ...  \
# 216                         877.3                            31.1  ...
#
#      Mobile-cellular subscriptions (per 100 inhabitants).1  \
# 216                                                5.4
#
#      Individuals using the Internet (per 100 inhabitants)  \
# 216                                               1082
#
# ...

# %%
#Tanzania change
df_renamed['Country']=df_renamed['Country'].replace(['UNITEDREPUBLICOFTANZANIA'], ['TANZANIA'])

# %%
#remerge after changes
df_merged=pd.merge(df, df_renamed, left_on='Country', right_on='Country')

# %%
df_merged.to_csv(r'C:\Users\jackm\Documents\Data Analytics\CW\2017Merge.csv', index = False)

# %%
#check and print null data

#outerjoin to determine missing values, only those missing or decided to drop remain
df_missing = pd.merge(df, df_renamed, on ='Country', how='left')
null_data = df_missing[df_missing.isnull().any(axis=1)]
print(null_data)
df_missing.to_csv(r'C:\Users\jackm\Documents\Data Analytics\CW\null.csv', index = False)
# Out:
#                    Country  Happiness.Rank  Happiness.Score  Whisker.high  \
# 32   TAIWANPROVINCEOFCHINA              33            6.422      6.494596
# 60             NORTHCYPRUS              61            5.810      5.897366
# 77                  KOSOVO              78            5.279      5.364848
# 127             IVORYCOAST             128            4.180      4.275183
#
#      Whisker.low  Economy..GDP.per.Capita.    Family  \
# 32      6.349404                  1.433627  1.384565
# 60      5.722633                  1.346911  1.186303
# 77      5.193152                  0.951484  1.137854
# 127     4.084817                  0.603049  0.904780
#
#      Health..Life.Expectancy.   Freedom  Generosity  ...  \
# 32                   0.793984  0.361467    0.258360  ...
# 60                   0.834647  0.471204    0.266846  ...
# 77                   0.541452  0.260288    0.319931  ...
# 127                  0.048642  0.447706    0.201237  ...
#
# ...
